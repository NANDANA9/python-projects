# %%
from tkinter import*
window=Tk()
window.title(' Simple Calculator')
window.geometry('300x300')

def click():
    entry1.insert(END,number)
  
    
def clear():
    entry1.delete(0,END)
    
def clear1():
    a=entry1.get()
    length=len(a)
    entry1.delete(length-1,END)

    
    
def operation():
    while True:
        global e
        m=entry1.get()
        r=str(m)
        w=eval(r)
        e=('=',w)
        return e

    

    
def final():
    global e
    operation()
    entry1.insert(END,e)
 

    
def error():
    try:
        final()
    except:
        clear()
        entry1.insert(END,'Syntax Error')
   
    

entry1=Entry(window,width=40)
entry1.place(x=10,y=10)

btn=Button(window,text='7',command=lambda:entry1.insert(END,'7'),width=5)
btn.place(x=40,y=60)

btn1=Button(window,text='8',command=lambda:entry1.insert(END,'8'),width=5)
btn1.place(x=90,y=60)

btn2=Button(window,text='9',command=lambda:entry1.insert(END,'9'),width=5)
btn2.place(x=140,y=60)

btn3=Button(window,text='4',command=lambda:entry1.insert(END,'4'),width=5)
btn3.place(x=40,y=90)

btn4=Button(window,text='5',command=lambda:entry1.insert(END,'5'),width=5)
btn4.place(x=90,y=90)

btn5=Button(window,text='6',command=lambda:entry1.insert(END,'6'),width=5)
btn5.place(x=140,y=90)

btn6=Button(window,text='1',command=lambda:entry1.insert(END,'1'),width=5)
btn6.place(x=40,y=120)

btn7=Button(window,text='2',command=lambda:entry1.insert(END,'2'),width=5)
btn7.place(x=90,y=120)

btn8=Button(window,text='3',command=lambda:entry1.insert(END,'3'),width=5)
btn8.place(x=140,y=120)

btn9=Button(window,text='.',command=lambda:entry1.insert(END,'.'),width=5)
btn9.place(x=40,y=150)

btn10=Button(window,text='+',command=lambda:entry1.insert(END,'+'),width=5)
btn10.place(x=190,y=60)

btn11=Button(window,text='-',command=lambda:entry1.insert(END,'-'),width=5)
btn11.place(x=190,y=90)

btn12=Button(window,text='x',command=lambda:entry1.insert(END,'*'),width=5)
btn12.place(x=190,y=120)

btn13=Button(window,text='0',command=lambda:entry1.insert(END,'0'),width=5)
btn13.place(x=90,y=150)

btn14=Button(window,text='/',command=lambda:entry1.insert(END,'/'),width=5)
btn14.place(x=190,y=150)

btn15=Button(window,text='%',command=lambda:entry1.insert(END,'%'),width=5)
btn15.place(x=140,y=150)

btn16=Button(window,text='Ac',command=clear,width=5)
btn16.place(x=40,y=180)

btn17=Button(window,text='C',command=clear1,width=5)
btn17.place(x=90,y=180)

btn18=Button(window,text='=',command=error,width=12,bg='gray')
btn18.place(x=140,y=180)



  
    
window.mainloop()

# %%
d='4543-45556'

# %%
eval(d)
# Out:
# -41013
