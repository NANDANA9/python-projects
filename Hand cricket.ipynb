# %%
a=input('enter name of player1:')
b='computer'


s=['head','tail']
c=input('enter head or tail :')
import random
d=random.choice(s)
print(d)


if d==c:
    current_player=a
    print('its',a,"'s turn")
else:
    current_player=b
    print(b,'turn')
   
    
    
    
def choose():
    global g
    global e
    if d==c:
        e=input('enter batting or bowling :')
        if e=='batting':
            print(a,"choose batting first")
            bad1()
        else:
            print(a,"choose bowling first")
            bad()
    else:
        f=['batting','bowling']
        import random
        g=random.choice(f)
        print('computer has decided to',g,'first')
        new()


def new():
    global g
    global e
    if g=='batting':
        e='bowling'
        bad()
    else:
        e='batting'
        g='bowling'
        bad1()

        
def player():
    global g
    global e
    if e=='batting':
        e='bowling'
        g='batting'
        bad2()
    elif g=='batting':
        e='batting'
        g='bowling'
        bad3()
        

def compu():
    global i
    h=[0,1,2,3,4,5,6]
    import random
    i=random.choice(h)
    print('computer choose',i)
    return i
    
               
def current_players():
    global current_player
    if current_player==b:
        current_player=a
    else:
        current_player=b  
               

    
def bad():
    global total
    total=0
    while True:
        global g
        global w
        global k
        k=input('enter a number between 0 to 6 :')
        if k=='0' or k=='1' or k=='2' or k=='3' or k=='4' or k=='5' or k=='6':
            k=int(k)
            print(k)
            w=compu()
            total=total+w
            if  i==k:
                total=total-w
                print('computer out')
                print('total score of computer',total)
                break
            else:
                print('current score is',total)
        else:
            pass

def bad1():
    global total1
    total1=0
    while True:
        global e
        global t
        global k
        k=input('enter a number between 0 to 6 :')
        if k=='0' or k=='1' or k=='2' or k=='3' or k=='4' or k=='5' or k=='6':
            k=int(k)
            print(k)
            t=compu()
            total1=total1+k
            if k==i:
                total1=total1-k
                print(a,'out')
                print('total score of',a,'is',total1)
                break

            else:    
                print('current score is',total1)

        else:
            pass


              
                
                
                
                
def bad2():
    global total
    total=0
    while True:
        global total1
        global s
        global g
        global k
        k=input('enter a number between 0 to 6 :')
        if k=='0' or k=='1' or k=='2' or k=='3' or k=='4' or k=='5' or k=='6':
            k=int(k)
            print(k)
            s=compu()
            total=total+s
            if  i==k:
                total=total-s
                print('computer out')
                print('total score of computer is',total)

                if total>total1:
                    print('computer won')
                    break
                elif total<total1:
                    print(a,'won')
                    break
                else:
                    print('tie')
                    break
            else:
                print('current score of computer is',total)
                if total>total1:
                    print('computer won')
                    break
                else:
                    pass
        else:
            pass
            


def bad3():
    global total1
    total1=0
    while True:
        global e
        global total
        global r
        global k
        k=input('enter a number between 0 to 6 :')
        if k=='0' or k=='1' or k=='2' or k=='3' or k=='4' or k=='5' or k=='6':
            k=int(k)
            print(k)
            r=compu()
            total1=total1+k
            if k==i:
                total1=total1-k
                print(a,'out')
                print('total score of',a,'is',total1)
                if total1>total:
                    print(a,'won')
                    break
                elif total>total1:
                    print('computer won')
                    break
                else:
                    print('tie')
                    break
            else:
                print('current score of ',a,' is',total1)
                if total1>total:
                    print(a, 'won')
                    break
                else:
                    pass

        else:
            pass

      
                
                
                
                
                
                

choose()
player()
print()
