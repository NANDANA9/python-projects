# %%
a=input('enter the name of player1:')
b=input('enter the name of player2:')

import random
c=[a,b]
e=random.choice(c)
current_player=e
print('its your turn',e)


d={7:' ',8:' ',9:' ',
   4:' ',5:' ',6:' ',
   1:' ',2:' ',3:' '}

dic={a:'x',b:'o'}

def board(d):
    print(f'{d[7]} | {d[8]} | {d[9]}')
    print('---','---','---')
    print(f'{d[4]} | {d[5]} | {d[6]}')
    print('---','---','---')
    print(f'{d[1]} | {d[2]} | {d[3]}')

def position():
    while True:
        global s
        s=input('enter the position between 1 to 9:')
        if s=='1' or s=='2' or s=='3' or s=='4' or s=='5' or s=='6' or s=='7' or s=='8'or s=='9':
            s=int(s)
            if d[s]=='x' or d[s]=='o':
                pass
            else:
                break
        else:
            pass
          

def current_players():
    global current_player
    if current_player==b:
        current_player=a
    else:
        current_player=b

        
def boards():
    if current_player==a:
        d[s]=dic[a]
    else:
        d[s]=dic[b]
    
        
        
def checking(d):
    global gameover
    gameover=False
    if d[7]==d[8]==d[9]=='x' or d[7]==d[8]==d[9]=='o':
        print('winner=',e)
        gameover=True
    elif d[4]==d[5]==d[6]=='x' or d[4]==d[5]==d[6]=='o':
        print('winner=',e)
        gameover=True
    elif d[1]==d[2]==d[3]=='x' or d[1]==d[2]==d[3]=='o':
        print('winner=',e)
        gameover=True
    elif d[7]==d[4]==d[1]=='x' or d[7]==d[4]==d[1]=='o':
        print('winner=',e)
        gameover=True
    elif d[8]==d[5]==d[2]=='x' or d[8]==d[5]==d[2]=='o':
        print('winner=',e)
        gameover=True
    elif d[9]==d[6]==d[3]=='x' or d[9]==d[6]==d[3]=='o':
        print('winner=',e)
        gameover=True
    elif d[7]==d[5]==d[3]=='x' or d[7]==d[5]==d[3]=='o':
        print('winner=',e)
        gameover=True
    elif d[9]==d[5]==d[1]=='x' or d[9]==d[5]==d[1]=='o':
        print('winner=',e)
        gameover=True
    elif (d[1]=='x' or d[1]=='o') and (d[2]=='x' or d[2]=='o') and (d[3]=='x' or d[3]=='o') and (d[4]=='x' or d[4]=='o') and (d[5]=='x' or d[5]=='o') and (d[6]=='x' or d[6]=='o') and (d[7]=='x' or d[7]=='o') and (d[8]=='x' or d[8]=='o') and (d[9]=='x' or d[9]=='o'):
        print('tie')
        gameover=True
    else: 
        return
    

position()
boards()    
board(d)    


while True:
    current_players()
    position()
    boards()
    board(d)
    checking(d)
    if gameover==True:
        break
# Out:
# enter the name of player1:hhdq
# enter the name of player2:kjj
# its your turn kjj
# enter the position between 1 to 9:2
#   |   |
# --- --- ---
#   |   |
# --- --- ---
#   | o |
# enter the position between 1 to 9:1
#   |   |
# --- --- ---
#   |   |
# --- --- ---
# x | o |
# enter the position between 1 to 9:5
#   |   |
# --- --- ---
#   | o |
# --- --- ---
# x | o |
# enter the position between 1 to 9:3
#   |   |
# --- --- ---
#   | o |
# --- --- ---
# x | o | x
# enter the position between 1 to 9:8
#   | o |
# --- --- ---
#   | o |
# --- --- ---
# x | o | x
# winner= kjj
